# %% [markdown]
# # Core Features: Lines and Planes in Parameter Space
#
# This example covers the basic features of the `loss-landscapes` library, i.e. evaluating a model's loss function along lines or planes in parameter space in order to produce visualizations of the loss landscape.

# %%
import sys
sys.path.append('../')

# libraries
import copy
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import numpy as np
import torch
import torch.nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.datasets as datasets
from tqdm import tqdm

matplotlib.rcParams['figure.figsize'] = [18, 12]

# code from this library - import the lines module
import loss_landscapes
import loss_landscapes.metrics

# %% [markdown]
# ## 1. Preliminary: Classifying MNIST
#
# This notebook demonstrates how to accomplish a simple task: visualizing the loss landscape of a small fully connected feed-forward neural network on the MNIST image classification task. In this section the preliminaries (the model and the training procedure) are setup.

# %%
# training hyperparameters
IN_DIM = 28 * 28
OUT_DIM = 10
LR = 10 ** -2
BATCH_SIZE = 512
EPOCHS = 25
# contour plot resolution
STEPS = 20
DIM = 3

# %% [markdown]
# The cells in this section contain no code specific to the `loss-landscapes` library.

# %%
class MLPSmall(torch.nn.Module):
    """ Fully connected feed-forward neural network with one hidden layer. """
    def __init__(self, x_dim, y_dim):
        super().__init__()
        self.linear_1 = torch.nn.Linear(x_dim, 32)
        self.linear_2 = torch.nn.Linear(32, y_dim)

    def forward(self, x):
        h = F.relu(self.linear_1(x))
        return F.softmax(self.linear_2(h), dim=1)


class Flatten(object):
    """ Transforms a PIL image to a flat numpy array. """
    def __call__(self, sample):
        return np.array(sample, dtype=np.float32).flatten()    
    

def train(model, optimizer, criterion, train_loader, epochs):
    """ Trains the given model with the given optimizer, loss function, etc. """
    model.train()
    # train model
    for _ in tqdm(range(epochs), 'Training'):
        for count, batch in enumerate(train_loader, 0):
            optimizer.zero_grad()
            x, y = batch

            pred = model(x)
            loss = criterion(pred, y)
            loss.backward()
            optimizer.step()

    model.eval()

# %% [markdown]
# We then create the model and an instance of the MNIST dataset.

# %%
# download MNIST and setup data loaders
mnist_train = datasets.MNIST(root='../data', train=True, download=True, transform=Flatten())
train_loader = torch.utils.data.DataLoader(mnist_train, batch_size=BATCH_SIZE, shuffle=False)

# define model
model = MLPSmall(IN_DIM, OUT_DIM)
optimizer = optim.Adam(model.parameters(), lr=LR)
criterion = torch.nn.CrossEntropyLoss()

# %% [markdown]
# ## 2. Points in Parameter Space
# The state of a neural network model represents a point in parameter space. Several functions in the `loss-landscapes` library require the user to provide instances of neural network models as arguments, where the model is taken to represent the point in parameter space corresponding to its parameters' state. Representing points as simply the models they relate to reduces the complexity of the client code.
#
# In the cell below, a copy of the model before training is made, to preserve the model's initial state.

# %%
# stores the initial point in parameter space
model_initial = copy.deepcopy(model)

# %% [markdown]
# Two common points of interest are the model initialization, and the model's final parameters after training. Similarly to the cell above, we can make a copy of the model after training. A copy of the model can be made at any time - this is up to the user, of course.

# %%
train(model, optimizer, criterion, train_loader, EPOCHS)

model_final = copy.deepcopy(model)
# Out:
# Training: 100%|█████████████████████████████████| 25/25 [01:08<00:00,  2.73s/it]

# %% [markdown]
# ## 3. Linear Interpolations of Loss between Two Points
#
# In the previous section, copies of the model before and after training were obtained. A common use case is to evaluate the model loss at a number of equidistant points along the straight line connecting the two points. Although care must be taken in interpreting such plots, the idea is to gain an insight into the smoothness of the landscape.
#
# The user might also be interested in collecting any other quantity along this line. The `loss-landscapes` library abstracts these details with entities called `Metric`s, which compute some quantity about a model for its current parameters. A number of pre-defined metrics is provided in the `loss_landscapes.metrics` package, and the user is free to write custom metrics. See the relevant documentation.
#
# An important metric is `Loss`, which applies a PyTorch loss function to a PyTorch model and returns the value produced.

# %%
# data that the evaluator will use when evaluating loss
x, y = iter(train_loader).__next__()
metric = loss_landscapes.metrics.Loss(criterion, x, y)

# compute loss data
loss_data = loss_landscapes.linear_interpolation(model_initial, model_final, metric, STEPS, deepcopy_model=True)

# %% [markdown]
# With the computed loss data, a linear interpolation plot can be rendered.

# %%
plt.plot([1/STEPS * i for i in range(STEPS)], loss_data)
plt.title('Linear Interpolation of Loss')
plt.xlabel('Interpolation Coefficient')
plt.ylabel('Loss')
axes = plt.gca()
# axes.set_ylim([2.300,2.325])
plt.show()

# %% [markdown]
# ## Experiment: Get n-dimensional "slice"

# %%
import loss_landscapes.model_interface.model_parameters as model_parameters
from loss_landscapes.model_interface.model_wrapper import ModelWrapper, wrap_model

mp = wrap_model(model_final).get_module_parameters()

n = 3
# Generate n random normal directions
axes = [ model_parameters.rand_u_like(mp) ]
for _ in range(n):
    axes += [ model_parameters.orthogonal_to(*axes) ]

print(len(axes))
print(model_parameters.check_all_normal(*axes))
# Out:
# 4
# 0.0009192228317260742
# -0.0003504157066345215
# -2.580881118774414e-05
# -6.079673767089844e-05
# 0.00011137127876281738
# -0.000133417546749115
# True

# %% [markdown]
# ## 4. Planar Approximations of Loss Around a Point
#
# Another core use for the library is producing 2-dimensional approximations of the loss-landscape topology around a point in parameter space. This is accomplished by sampling two random direction vectors in parameter space, and computing the loss at a number of points on the plane defined by the two vectors:

# %%
loss_data_fin = loss_landscapes.random_plane(model_final, metric, 20, STEPS, normalization='filter', deepcopy_model=True)

# %% [markdown]
# The loss values on this plane can be visualized in an intuitive and interpretable manner using contour plots or 3D surface plots:

# %%
plt.contour(loss_data_fin, levels=60)
plt.title('Loss Contours around Trained Model')
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
X = np.array([[j for j in range(STEPS)] for i in range(STEPS)])
Y = np.array([[i for _ in range(STEPS)] for i in range(STEPS)])
ax.plot_surface(X, Y, loss_data_fin, rstride=1, cstride=1, cmap='viridis', edgecolor='none')
ax.set_title('Surface Plot of Loss Landscape')
fig.show()
# Out:
# /tmp/ipykernel_47100/16927094.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Experiment: Get n-dimensional loss matrix

# %%
loss_data_fin_n_dim = loss_landscapes.random_n_directions(model_final, metric, DIM, 20, STEPS, normalization='filter', deepcopy_model=True)

print(loss_data_fin_n_dim.shape)
# Out:
# Generate one subspace with the dimension of 3
# -0.0005299150943756104
# 0.00034230947494506836
# -0.00012537837028503418
# All subspace directions are nearly orthogonal to each other
# The loss value at (0, 0, 1) is 2
# The loss value at (0, 1, 0) is 2
# The loss value at (0, 1, 1) is 2
# The loss value at (1, 0, 0) is 2
# The loss value at (1, 0, 1) is 2
# The loss value at (1, 1, 0) is 2
# The loss value at (1, 1, 1) is 2
# The loss value at (0, 0, 2) is 2
# The loss value at (0, 1, 2) is 2
# The loss value at (1, 0, 2) is 2
# The loss value at (1, 1, 2) is 2
# The loss value at (0, 2, 0) is 2
# The loss value at (0, 2, 1) is 2
# The loss value at (1, 2, 0) is 2
# The loss value at (1, 2, 1) is 2
# The loss value at (0, 2, 2) is 2
# The loss value at (1, 2, 2) is 2
# The loss value at (2, 0, 0) is 2
# The loss value at (2, 0, 1) is 2
# The loss value at (2, 1, 0) is 2
# The loss value at (2, 1, 1) is 2
# The loss value at (2, 0, 2) is 2
# The loss value at (2, 1, 2) is 2
# The loss value at (2, 2, 0) is 2
# The loss value at (2, 2, 1) is 2
# The loss value at (2, 2, 2) is 2
# The loss value at (0, 0, 3) is 2
# The loss value at (0, 1, 3) is 2
# The loss value at (1, 0, 3) is 2
# The loss value at (1, 1, 3) is 2
# The loss value at (0, 2, 3) is 2
# The loss value at (1, 2, 3) is 2
# The loss value at (2, 0, 3) is 2
# The loss value at (2, 1, 3) is 2
# The loss value at (2, 2, 3) is 2
# The loss value at (0, 3, 0) is 2
# The loss value at (0, 3, 1) is 2
# The loss value at (1, 3, 0) is 2
# The loss value at (1, 3, 1) is 2
# The loss value at (0, 3, 2) is 2
# The loss value at (1, 3, 2) is 2
# The loss value at (2, 3, 0) is 2
# The loss value at (2, 3, 1) is 2
# The loss value at (2, 3, 2) is 2
# The loss value at (0, 3, 3) is 2
# The loss value at (1, 3, 3) is 2
# The loss value at (2, 3, 3) is 2
# The loss value at (3, 0, 0) is 2
# The loss value at (3, 0, 1) is 2
# The loss value at (3, 1, 0) is 2
# The loss value at (3, 1, 1) is 2
# The loss value at (3, 0, 2) is 2
# The loss value at (3, 1, 2) is 2
# The loss value at (3, 2, 0) is 2
# The loss value at (3, 2, 1) is 2
# The loss value at (3, 2, 2) is 2
# The loss value at (3, 0, 3) is 2
# The loss value at (3, 1, 3) is 2
# The loss value at (3, 2, 3) is 2
# The loss value at (3, 3, 0) is 2
# The loss value at (3, 3, 1) is 2
# The loss value at (3, 3, 2) is 2
# The loss value at (3, 3, 3) is 2
# The loss value at (0, 0, 4) is 2
# The loss value at (0, 1, 4) is 2
# The loss value at (1, 0, 4) is 2
# The loss value at (1, 1, 4) is 2
# The loss value at (0, 2, 4) is 2
# The loss value at (1, 2, 4) is 2
# The loss value at (2, 0, 4) is 2
# The loss value at (2, 1, 4) is 2
# The loss value at (2, 2, 4) is 2
# The loss value at (0, 3, 4) is 2
# The loss value at (1, 3, 4) is 2
# The loss value at (2, 3, 4) is 2
# The loss value at (3, 0, 4) is 2
# The loss value at (3, 1, 4) is 2
# The loss value at (3, 2, 4) is 2
# The loss value at (3, 3, 4) is 2
# The loss value at (0, 4, 0) is 2
# The loss value at (0, 4, 1) is 2
# The loss value at (1, 4, 0) is 2
# The loss value at (1, 4, 1) is 2
# The loss value at (0, 4, 2) is 2
# The loss value at (1, 4, 2) is 2
# The loss value at (2, 4, 0) is 2
# The loss value at (2, 4, 1) is 2
# The loss value at (2, 4, 2) is 2
# The loss value at (0, 4, 3) is 2
# The loss value at (1, 4, 3) is 2
# The loss value at (2, 4, 3) is 2
# The loss value at (3, 4, 0) is 2
# The loss value at (3, 4, 1) is 2
# The loss value at (3, 4, 2) is 2
# The loss value at (3, 4, 3) is 2
# The loss value at (0, 4, 4) is 2
# The loss value at (1, 4, 4) is 2
# The loss value at (2, 4, 4) is 2
# The loss value at (3, 4, 4) is 2
# The loss value at (4, 0, 0) is 2
# The loss value at (4, 0, 1) is 2
# The loss value at (4, 1, 0) is 2
# The loss value at (4, 1, 1) is 2
# The loss value at (4, 0, 2) is 2
# The loss value at (4, 1, 2) is 2
# The loss value at (4, 2, 0) is 2
# The loss value at (4, 2, 1) is 2
# The loss value at (4, 2, 2) is 2
# The loss value at (4, 0, 3) is 2
# The loss value at (4, 1, 3) is 2
# The loss value at (4, 2, 3) is 2
# The loss value at (4, 3, 0) is 2
# The loss value at (4, 3, 1) is 2
# The loss value at (4, 3, 2) is 2
# The loss value at (4, 3, 3) is 2
# The loss value at (4, 0, 4) is 2
# The loss value at (4, 1, 4) is 2
# The loss value at (4, 2, 4) is 2
# The loss value at (4, 3, 4) is 2
# The loss value at (4, 4, 0) is 2
# The loss value at (4, 4, 1) is 2
# The loss value at (4, 4, 2) is 2
# The loss value at (4, 4, 3) is 2
# The loss value at (4, 4, 4) is 2
# The loss value at (0, 0, 5) is 2
# The loss value at (0, 1, 5) is 2
# The loss value at (1, 0, 5) is 2
# The loss value at (1, 1, 5) is 2
# The loss value at (0, 2, 5) is 2
# The loss value at (1, 2, 5) is 2
# The loss value at (2, 0, 5) is 2
# The loss value at (2, 1, 5) is 2
# The loss value at (2, 2, 5) is 2
# The loss value at (0, 3, 5) is 2
# The loss value at (1, 3, 5) is 2
# The loss value at (2, 3, 5) is 2
# The loss value at (3, 0, 5) is 2
# The loss value at (3, 1, 5) is 2
# The loss value at (3, 2, 5) is 2
# The loss value at (3, 3, 5) is 2
# The loss value at (0, 4, 5) is 2
# The loss value at (1, 4, 5) is 2
# The loss value at (2, 4, 5) is 2
# The loss value at (3, 4, 5) is 2
# The loss value at (4, 0, 5) is 2
# The loss value at (4, 1, 5) is 2
# The loss value at (4, 2, 5) is 2
# The loss value at (4, 3, 5) is 2
# The loss value at (4, 4, 5) is 2
# The loss value at (0, 5, 0) is 2
# The loss value at (0, 5, 1) is 2
# The loss value at (1, 5, 0) is 2
# The loss value at (1, 5, 1) is 2
# The loss value at (0, 5, 2) is 2
# The loss value at (1, 5, 2) is 2
# The loss value at (2, 5, 0) is 2
# The loss value at (2, 5, 1) is 2
# The loss value at (2, 5, 2) is 2
# The loss value at (0, 5, 3) is 2
# The loss value at (1, 5, 3) is 2
# The loss value at (2, 5, 3) is 2
# The loss value at (3, 5, 0) is 2
# The loss value at (3, 5, 1) is 2
# The loss value at (3, 5, 2) is 2
# The loss value at (3, 5, 3) is 2
# The loss value at (0, 5, 4) is 2
# The loss value at (1, 5, 4) is 2
# The loss value at (2, 5, 4) is 2
# The loss value at (3, 5, 4) is 2
# The loss value at (4, 5, 0) is 2
# The loss value at (4, 5, 1) is 2
# The loss value at (4, 5, 2) is 2
# The loss value at (4, 5, 3) is 2
# The loss value at (4, 5, 4) is 2
# The loss value at (0, 5, 5) is 2
# The loss value at (1, 5, 5) is 2
# The loss value at (2, 5, 5) is 2
# The loss value at (3, 5, 5) is 2
# The loss value at (4, 5, 5) is 2
# The loss value at (5, 0, 0) is 2
# The loss value at (5, 0, 1) is 2
# The loss value at (5, 1, 0) is 2
# The loss value at (5, 1, 1) is 2
# The loss value at (5, 0, 2) is 2
# The loss value at (5, 1, 2) is 2
# The loss value at (5, 2, 0) is 2
# The loss value at (5, 2, 1) is 2
# The loss value at (5, 2, 2) is 2
# The loss value at (5, 0, 3) is 2
# The loss value at (5, 1, 3) is 2
# The loss value at (5, 2, 3) is 2
# The loss value at (5, 3, 0) is 2
# The loss value at (5, 3, 1) is 2
# The loss value at (5, 3, 2) is 2
# The loss value at (5, 3, 3) is 2
# The loss value at (5, 0, 4) is 2
# The loss value at (5, 1, 4) is 2
# The loss value at (5, 2, 4) is 2
# The loss value at (5, 3, 4) is 2
# The loss value at (5, 4, 0) is 2
# The loss value at (5, 4, 1) is 2
# The loss value at (5, 4, 2) is 2
# The loss value at (5, 4, 3) is 2
# The loss value at (5, 4, 4) is 2
# The loss value at (5, 0, 5) is 2
# The loss value at (5, 1, 5) is 2
# The loss value at (5, 2, 5) is 2
# The loss value at (5, 3, 5) is 2
# The loss value at (5, 4, 5) is 2
# The loss value at (5, 5, 0) is 2
# The loss value at (5, 5, 1) is 2
# The loss value at (5, 5, 2) is 2
# The loss value at (5, 5, 3) is 2
# The loss value at (5, 5, 4) is 2
# The loss value at (5, 5, 5) is 2
# The loss value at (0, 0, 6) is 2
# The loss value at (0, 1, 6) is 2
# The loss value at (1, 0, 6) is 2
# The loss value at (1, 1, 6) is 2
# The loss value at (0, 2, 6) is 2
# The loss value at (1, 2, 6) is 2
# The loss value at (2, 0, 6) is 2
# The loss value at (2, 1, 6) is 2
# The loss value at (2, 2, 6) is 2
# The loss value at (0, 3, 6) is 2
# The loss value at (1, 3, 6) is 2
# The loss value at (2, 3, 6) is 2
# The loss value at (3, 0, 6) is 2
# The loss value at (3, 1, 6) is 2
# The loss value at (3, 2, 6) is 2
# The loss value at (3, 3, 6) is 2
# The loss value at (0, 4, 6) is 2
# The loss value at (1, 4, 6) is 2
# The loss value at (2, 4, 6) is 2
# The loss value at (3, 4, 6) is 2
# The loss value at (4, 0, 6) is 2
# The loss value at (4, 1, 6) is 2
# The loss value at (4, 2, 6) is 2
# The loss value at (4, 3, 6) is 2
# The loss value at (4, 4, 6) is 2
# The loss value at (0, 5, 6) is 2
# The loss value at (1, 5, 6) is 2
# The loss value at (2, 5, 6) is 2
# The loss value at (3, 5, 6) is 2
# The loss value at (4, 5, 6) is 2
# The loss value at (5, 0, 6) is 2
# The loss value at (5, 1, 6) is 2
# The loss value at (5, 2, 6) is 2
# The loss value at (5, 3, 6) is 2
# The loss value at (5, 4, 6) is 2
# The loss value at (5, 5, 6) is 2
# The loss value at (0, 6, 0) is 2
# The loss value at (0, 6, 1) is 2
# The loss value at (1, 6, 0) is 2
# The loss value at (1, 6, 1) is 2
# The loss value at (0, 6, 2) is 2
# The loss value at (1, 6, 2) is 2
# The loss value at (2, 6, 0) is 2
# The loss value at (2, 6, 1) is 2
# The loss value at (2, 6, 2) is 2
# The loss value at (0, 6, 3) is 2
# The loss value at (1, 6, 3) is 2
# The loss value at (2, 6, 3) is 2
# The loss value at (3, 6, 0) is 2
# The loss value at (3, 6, 1) is 2
# The loss value at (3, 6, 2) is 2
# The loss value at (3, 6, 3) is 2
# The loss value at (0, 6, 4) is 2
# The loss value at (1, 6, 4) is 2
# The loss value at (2, 6, 4) is 2
# The loss value at (3, 6, 4) is 2
# The loss value at (4, 6, 0) is 2
# The loss value at (4, 6, 1) is 2
# The loss value at (4, 6, 2) is 2
# The loss value at (4, 6, 3) is 2
# The loss value at (4, 6, 4) is 2
# The loss value at (0, 6, 5) is 2
# The loss value at (1, 6, 5) is 2
# The loss value at (2, 6, 5) is 2
# The loss value at (3, 6, 5) is 2
# The loss value at (4, 6, 5) is 2
# The loss value at (5, 6, 0) is 2
# The loss value at (5, 6, 1) is 2
# The loss value at (5, 6, 2) is 2
# The loss value at (5, 6, 3) is 2
# The loss value at (5, 6, 4) is 2
# The loss value at (5, 6, 5) is 2
# The loss value at (0, 6, 6) is 2
# The loss value at (1, 6, 6) is 2
# The loss value at (2, 6, 6) is 2
# The loss value at (3, 6, 6) is 2
# The loss value at (4, 6, 6) is 2
# The loss value at (5, 6, 6) is 2
# The loss value at (6, 0, 0) is 2
# The loss value at (6, 0, 1) is 2
# The loss value at (6, 1, 0) is 2
# The loss value at (6, 1, 1) is 2
# The loss value at (6, 0, 2) is 2
# The loss value at (6, 1, 2) is 2
# The loss value at (6, 2, 0) is 2
# The loss value at (6, 2, 1) is 2
# The loss value at (6, 2, 2) is 2
# The loss value at (6, 0, 3) is 2
# The loss value at (6, 1, 3) is 2
# The loss value at (6, 2, 3) is 2
# The loss value at (6, 3, 0) is 2
# The loss value at (6, 3, 1) is 2
# The loss value at (6, 3, 2) is 2
# The loss value at (6, 3, 3) is 2
# The loss value at (6, 0, 4) is 2
# The loss value at (6, 1, 4) is 2
# The loss value at (6, 2, 4) is 2
# The loss value at (6, 3, 4) is 2
# The loss value at (6, 4, 0) is 2
# The loss value at (6, 4, 1) is 2
# The loss value at (6, 4, 2) is 2
# The loss value at (6, 4, 3) is 2
# The loss value at (6, 4, 4) is 2
# The loss value at (6, 0, 5) is 2
# The loss value at (6, 1, 5) is 2
# The loss value at (6, 2, 5) is 2
# The loss value at (6, 3, 5) is 2
# The loss value at (6, 4, 5) is 2
# The loss value at (6, 5, 0) is 2
# The loss value at (6, 5, 1) is 2
# The loss value at (6, 5, 2) is 2
# The loss value at (6, 5, 3) is 2
# The loss value at (6, 5, 4) is 2
# The loss value at (6, 5, 5) is 2
# The loss value at (6, 0, 6) is 2
# The loss value at (6, 1, 6) is 2
# The loss value at (6, 2, 6) is 2
# The loss value at (6, 3, 6) is 2
# The loss value at (6, 4, 6) is 2
# The loss value at (6, 5, 6) is 2
# The loss value at (6, 6, 0) is 2
# The loss value at (6, 6, 1) is 2
# The loss value at (6, 6, 2) is 2
# The loss value at (6, 6, 3) is 2
# The loss value at (6, 6, 4) is 2
# The loss value at (6, 6, 5) is 2
# The loss value at (6, 6, 6) is 2
# The loss value at (0, 0, 7) is 2
# The loss value at (0, 1, 7) is 2
# The loss value at (1, 0, 7) is 2
# The loss value at (1, 1, 7) is 2
# The loss value at (0, 2, 7) is 2
# The loss value at (1, 2, 7) is 2
# The loss value at (2, 0, 7) is 2
# The loss value at (2, 1, 7) is 2
# The loss value at (2, 2, 7) is 2
# The loss value at (0, 3, 7) is 2
# The loss value at (1, 3, 7) is 2
# The loss value at (2, 3, 7) is 2
# The loss value at (3, 0, 7) is 2
# The loss value at (3, 1, 7) is 2
# The loss value at (3, 2, 7) is 2
# The loss value at (3, 3, 7) is 2
# The loss value at (0, 4, 7) is 2
# The loss value at (1, 4, 7) is 2
# The loss value at (2, 4, 7) is 2
# The loss value at (3, 4, 7) is 2
# The loss value at (4, 0, 7) is 2
# The loss value at (4, 1, 7) is 2
# The loss value at (4, 2, 7) is 2
# The loss value at (4, 3, 7) is 2
# The loss value at (4, 4, 7) is 2
# The loss value at (0, 5, 7) is 2
# The loss value at (1, 5, 7) is 2
# The loss value at (2, 5, 7) is 2
# The loss value at (3, 5, 7) is 2
# The loss value at (4, 5, 7) is 2
# The loss value at (5, 0, 7) is 2
# The loss value at (5, 1, 7) is 2
# The loss value at (5, 2, 7) is 2
# The loss value at (5, 3, 7) is 2
# The loss value at (5, 4, 7) is 2
# The loss value at (5, 5, 7) is 2
# The loss value at (0, 6, 7) is 2
# The loss value at (1, 6, 7) is 2
# The loss value at (2, 6, 7) is 2
# The loss value at (3, 6, 7) is 2
# The loss value at (4, 6, 7) is 2
# The loss value at (5, 6, 7) is 2
# The loss value at (6, 0, 7) is 2
# The loss value at (6, 1, 7) is 2
# The loss value at (6, 2, 7) is 2
# The loss value at (6, 3, 7) is 2
# The loss value at (6, 4, 7) is 2
# The loss value at (6, 5, 7) is 2
# The loss value at (6, 6, 7) is 2
# The loss value at (0, 7, 0) is 2
# The loss value at (0, 7, 1) is 2
# The loss value at (1, 7, 0) is 2
# The loss value at (1, 7, 1) is 2
# The loss value at (0, 7, 2) is 2
# The loss value at (1, 7, 2) is 2
# The loss value at (2, 7, 0) is 2
# The loss value at (2, 7, 1) is 2
# The loss value at (2, 7, 2) is 2
# The loss value at (0, 7, 3) is 2
# The loss value at (1, 7, 3) is 2
# The loss value at (2, 7, 3) is 2
# The loss value at (3, 7, 0) is 2
# The loss value at (3, 7, 1) is 2
# The loss value at (3, 7, 2) is 2
# The loss value at (3, 7, 3) is 2
# The loss value at (0, 7, 4) is 2
# The loss value at (1, 7, 4) is 2
# The loss value at (2, 7, 4) is 2
# The loss value at (3, 7, 4) is 2
# The loss value at (4, 7, 0) is 2
# The loss value at (4, 7, 1) is 2
# The loss value at (4, 7, 2) is 2
# The loss value at (4, 7, 3) is 2
# The loss value at (4, 7, 4) is 2
# The loss value at (0, 7, 5) is 2
# The loss value at (1, 7, 5) is 2
# The loss value at (2, 7, 5) is 2
# The loss value at (3, 7, 5) is 2
# The loss value at (4, 7, 5) is 2
# The loss value at (5, 7, 0) is 2
# The loss value at (5, 7, 1) is 2
# The loss value at (5, 7, 2) is 2
# The loss value at (5, 7, 3) is 2
# The loss value at (5, 7, 4) is 2
# The loss value at (5, 7, 5) is 2
# The loss value at (0, 7, 6) is 2
# The loss value at (1, 7, 6) is 2
# The loss value at (2, 7, 6) is 2
# The loss value at (3, 7, 6) is 2
# The loss value at (4, 7, 6) is 2
# The loss value at (5, 7, 6) is 2
# The loss value at (6, 7, 0) is 2
# The loss value at (6, 7, 1) is 2
# The loss value at (6, 7, 2) is 2
# The loss value at (6, 7, 3) is 2
# The loss value at (6, 7, 4) is 2
# The loss value at (6, 7, 5) is 2
# The loss value at (6, 7, 6) is 2
# The loss value at (0, 7, 7) is 2
# The loss value at (1, 7, 7) is 2
# The loss value at (2, 7, 7) is 2
# The loss value at (3, 7, 7) is 2
# The loss value at (4, 7, 7) is 2
# The loss value at (5, 7, 7) is 2
# The loss value at (6, 7, 7) is 2
# The loss value at (7, 0, 0) is 2
# The loss value at (7, 0, 1) is 2
# The loss value at (7, 1, 0) is 2
# The loss value at (7, 1, 1) is 2
# The loss value at (7, 0, 2) is 2
# The loss value at (7, 1, 2) is 2
# The loss value at (7, 2, 0) is 2
# The loss value at (7, 2, 1) is 2
# The loss value at (7, 2, 2) is 2
# The loss value at (7, 0, 3) is 2
# The loss value at (7, 1, 3) is 2
# The loss value at (7, 2, 3) is 2
# The loss value at (7, 3, 0) is 2
# The loss value at (7, 3, 1) is 2
# The loss value at (7, 3, 2) is 2
# The loss value at (7, 3, 3) is 2
# The loss value at (7, 0, 4) is 2
# The loss value at (7, 1, 4) is 2
# The loss value at (7, 2, 4) is 2
# The loss value at (7, 3, 4) is 2
# The loss value at (7, 4, 0) is 2
# The loss value at (7, 4, 1) is 2
# The loss value at (7, 4, 2) is 2
# The loss value at (7, 4, 3) is 2
# The loss value at (7, 4, 4) is 2
# The loss value at (7, 0, 5) is 2
# The loss value at (7, 1, 5) is 2
# The loss value at (7, 2, 5) is 2
# The loss value at (7, 3, 5) is 2
# The loss value at (7, 4, 5) is 2
# The loss value at (7, 5, 0) is 2
# The loss value at (7, 5, 1) is 2
# The loss value at (7, 5, 2) is 2
# The loss value at (7, 5, 3) is 2
# The loss value at (7, 5, 4) is 2
# The loss value at (7, 5, 5) is 2
# The loss value at (7, 0, 6) is 2
# The loss value at (7, 1, 6) is 2
# The loss value at (7, 2, 6) is 2
# The loss value at (7, 3, 6) is 2
# The loss value at (7, 4, 6) is 2
# The loss value at (7, 5, 6) is 2
# The loss value at (7, 6, 0) is 2
# The loss value at (7, 6, 1) is 2
# The loss value at (7, 6, 2) is 2
# The loss value at (7, 6, 3) is 2
# The loss value at (7, 6, 4) is 2
# The loss value at (7, 6, 5) is 2
# The loss value at (7, 6, 6) is 2
# The loss value at (7, 0, 7) is 2
# The loss value at (7, 1, 7) is 2
# The loss value at (7, 2, 7) is 2
# The loss value at (7, 3, 7) is 2
# The loss value at (7, 4, 7) is 2
# The loss value at (7, 5, 7) is 2
# The loss value at (7, 6, 7) is 2
# The loss value at (7, 7, 0) is 2
# The loss value at (7, 7, 1) is 2
# The loss value at (7, 7, 2) is 2
# The loss value at (7, 7, 3) is 2
# The loss value at (7, 7, 4) is 2
# The loss value at (7, 7, 5) is 2
# The loss value at (7, 7, 6) is 2
# The loss value at (7, 7, 7) is 2
# The loss value at (0, 0, 8) is 2
# The loss value at (0, 1, 8) is 2
# The loss value at (1, 0, 8) is 2
# The loss value at (1, 1, 8) is 2
# The loss value at (0, 2, 8) is 2
# The loss value at (1, 2, 8) is 2
# The loss value at (2, 0, 8) is 2
# The loss value at (2, 1, 8) is 2
# The loss value at (2, 2, 8) is 2
# The loss value at (0, 3, 8) is 2
# The loss value at (1, 3, 8) is 2
# The loss value at (2, 3, 8) is 2
# The loss value at (3, 0, 8) is 2
# The loss value at (3, 1, 8) is 2
# The loss value at (3, 2, 8) is 2
# The loss value at (3, 3, 8) is 2
# The loss value at (0, 4, 8) is 2
# The loss value at (1, 4, 8) is 2
# The loss value at (2, 4, 8) is 2
# The loss value at (3, 4, 8) is 2
# The loss value at (4, 0, 8) is 2
# The loss value at (4, 1, 8) is 2
# The loss value at (4, 2, 8) is 2
# The loss value at (4, 3, 8) is 2
# The loss value at (4, 4, 8) is 2
# The loss value at (0, 5, 8) is 2
# The loss value at (1, 5, 8) is 2
# The loss value at (2, 5, 8) is 2
# The loss value at (3, 5, 8) is 2
# The loss value at (4, 5, 8) is 2
# The loss value at (5, 0, 8) is 2
# The loss value at (5, 1, 8) is 2
# The loss value at (5, 2, 8) is 2
# The loss value at (5, 3, 8) is 2
# The loss value at (5, 4, 8) is 2
# The loss value at (5, 5, 8) is 2
# The loss value at (0, 6, 8) is 2
# The loss value at (1, 6, 8) is 2
# The loss value at (2, 6, 8) is 2
# The loss value at (3, 6, 8) is 2
# The loss value at (4, 6, 8) is 2
# The loss value at (5, 6, 8) is 2
# The loss value at (6, 0, 8) is 2
# The loss value at (6, 1, 8) is 2
# The loss value at (6, 2, 8) is 2
# The loss value at (6, 3, 8) is 2
# The loss value at (6, 4, 8) is 2
# The loss value at (6, 5, 8) is 2
# The loss value at (6, 6, 8) is 2
# The loss value at (0, 7, 8) is 2
# The loss value at (1, 7, 8) is 2
# The loss value at (2, 7, 8) is 2
# The loss value at (3, 7, 8) is 2
# The loss value at (4, 7, 8) is 2
# The loss value at (5, 7, 8) is 2
# The loss value at (6, 7, 8) is 2
# The loss value at (7, 0, 8) is 2
# The loss value at (7, 1, 8) is 2
# The loss value at (7, 2, 8) is 2
# The loss value at (7, 3, 8) is 2
# The loss value at (7, 4, 8) is 2
# The loss value at (7, 5, 8) is 2
# The loss value at (7, 6, 8) is 2
# The loss value at (7, 7, 8) is 2
# The loss value at (0, 8, 0) is 2
# The loss value at (0, 8, 1) is 2
# The loss value at (1, 8, 0) is 2
# The loss value at (1, 8, 1) is 2
# The loss value at (0, 8, 2) is 2
# The loss value at (1, 8, 2) is 2
# The loss value at (2, 8, 0) is 2
# The loss value at (2, 8, 1) is 2
# The loss value at (2, 8, 2) is 2
# The loss value at (0, 8, 3) is 2
# The loss value at (1, 8, 3) is 2
# The loss value at (2, 8, 3) is 2
# The loss value at (3, 8, 0) is 2
# The loss value at (3, 8, 1) is 2
# The loss value at (3, 8, 2) is 2
# The loss value at (3, 8, 3) is 2
# The loss value at (0, 8, 4) is 2
# The loss value at (1, 8, 4) is 2
# The loss value at (2, 8, 4) is 2
# The loss value at (3, 8, 4) is 2
# The loss value at (4, 8, 0) is 2
# The loss value at (4, 8, 1) is 2
# The loss value at (4, 8, 2) is 2
# The loss value at (4, 8, 3) is 2
# The loss value at (4, 8, 4) is 2
# The loss value at (0, 8, 5) is 2
# The loss value at (1, 8, 5) is 2
# The loss value at (2, 8, 5) is 2
# The loss value at (3, 8, 5) is 2
# The loss value at (4, 8, 5) is 2
# The loss value at (5, 8, 0) is 2
# The loss value at (5, 8, 1) is 2
# The loss value at (5, 8, 2) is 2
# The loss value at (5, 8, 3) is 2
# The loss value at (5, 8, 4) is 2
# The loss value at (5, 8, 5) is 2
# The loss value at (0, 8, 6) is 2
# The loss value at (1, 8, 6) is 2
# The loss value at (2, 8, 6) is 2
# The loss value at (3, 8, 6) is 2
# The loss value at (4, 8, 6) is 2
# The loss value at (5, 8, 6) is 2
# The loss value at (6, 8, 0) is 2
# The loss value at (6, 8, 1) is 2
# The loss value at (6, 8, 2) is 2
# The loss value at (6, 8, 3) is 2
# The loss value at (6, 8, 4) is 2
# The loss value at (6, 8, 5) is 2
# The loss value at (6, 8, 6) is 2
# The loss value at (0, 8, 7) is 2
# The loss value at (1, 8, 7) is 2
# The loss value at (2, 8, 7) is 2
# The loss value at (3, 8, 7) is 2
# The loss value at (4, 8, 7) is 2
# The loss value at (5, 8, 7) is 2
# The loss value at (6, 8, 7) is 2
# The loss value at (7, 8, 0) is 2
# The loss value at (7, 8, 1) is 2
# The loss value at (7, 8, 2) is 2
# The loss value at (7, 8, 3) is 2
# The loss value at (7, 8, 4) is 2
# The loss value at (7, 8, 5) is 2
# The loss value at (7, 8, 6) is 2
# The loss value at (7, 8, 7) is 2
# The loss value at (0, 8, 8) is 2
# The loss value at (1, 8, 8) is 2
# The loss value at (2, 8, 8) is 2
# The loss value at (3, 8, 8) is 2
# The loss value at (4, 8, 8) is 2
# The loss value at (5, 8, 8) is 2
# The loss value at (6, 8, 8) is 2
# The loss value at (7, 8, 8) is 2
# The loss value at (8, 0, 0) is 2
# The loss value at (8, 0, 1) is 2
# The loss value at (8, 1, 0) is 2
# The loss value at (8, 1, 1) is 2
# The loss value at (8, 0, 2) is 2
# The loss value at (8, 1, 2) is 2
# The loss value at (8, 2, 0) is 2
# The loss value at (8, 2, 1) is 2
# The loss value at (8, 2, 2) is 2
# The loss value at (8, 0, 3) is 2
# The loss value at (8, 1, 3) is 2
# The loss value at (8, 2, 3) is 2
# The loss value at (8, 3, 0) is 2
# The loss value at (8, 3, 1) is 2
# The loss value at (8, 3, 2) is 2
# The loss value at (8, 3, 3) is 2
# The loss value at (8, 0, 4) is 2
# The loss value at (8, 1, 4) is 2
# The loss value at (8, 2, 4) is 2
# The loss value at (8, 3, 4) is 2
# The loss value at (8, 4, 0) is 2
# The loss value at (8, 4, 1) is 2
# The loss value at (8, 4, 2) is 2
# The loss value at (8, 4, 3) is 2
# The loss value at (8, 4, 4) is 2
# The loss value at (8, 0, 5) is 2
# The loss value at (8, 1, 5) is 2
# The loss value at (8, 2, 5) is 2
# The loss value at (8, 3, 5) is 2
# The loss value at (8, 4, 5) is 2
# The loss value at (8, 5, 0) is 2
# The loss value at (8, 5, 1) is 2
# The loss value at (8, 5, 2) is 2
# The loss value at (8, 5, 3) is 2
# The loss value at (8, 5, 4) is 2
# The loss value at (8, 5, 5) is 2
# The loss value at (8, 0, 6) is 2
# The loss value at (8, 1, 6) is 2
# The loss value at (8, 2, 6) is 2
# The loss value at (8, 3, 6) is 2
# The loss value at (8, 4, 6) is 2
# The loss value at (8, 5, 6) is 2
# The loss value at (8, 6, 0) is 2
# The loss value at (8, 6, 1) is 2
# The loss value at (8, 6, 2) is 2
# The loss value at (8, 6, 3) is 2
# The loss value at (8, 6, 4) is 2
# The loss value at (8, 6, 5) is 2
# The loss value at (8, 6, 6) is 2
# The loss value at (8, 0, 7) is 2
# The loss value at (8, 1, 7) is 2
# The loss value at (8, 2, 7) is 2
# The loss value at (8, 3, 7) is 2
# The loss value at (8, 4, 7) is 2
# The loss value at (8, 5, 7) is 2
# The loss value at (8, 6, 7) is 2
# The loss value at (8, 7, 0) is 2
# The loss value at (8, 7, 1) is 2
# The loss value at (8, 7, 2) is 2
# The loss value at (8, 7, 3) is 2
# The loss value at (8, 7, 4) is 2
# The loss value at (8, 7, 5) is 2
# The loss value at (8, 7, 6) is 2
# The loss value at (8, 7, 7) is 2
# The loss value at (8, 0, 8) is 2
# The loss value at (8, 1, 8) is 2
# The loss value at (8, 2, 8) is 2
# The loss value at (8, 3, 8) is 2
# The loss value at (8, 4, 8) is 2
# The loss value at (8, 5, 8) is 2
# The loss value at (8, 6, 8) is 2
# The loss value at (8, 7, 8) is 2
# The loss value at (8, 8, 0) is 2
# The loss value at (8, 8, 1) is 2
# The loss value at (8, 8, 2) is 2
# The loss value at (8, 8, 3) is 2
# The loss value at (8, 8, 4) is 2
# The loss value at (8, 8, 5) is 2
# The loss value at (8, 8, 6) is 2
# The loss value at (8, 8, 7) is 2
# The loss value at (8, 8, 8) is 2
# The loss value at (0, 0, 9) is 2
# The loss value at (0, 1, 9) is 2
# The loss value at (1, 0, 9) is 2
# The loss value at (1, 1, 9) is 2
# The loss value at (0, 2, 9) is 2
# The loss value at (1, 2, 9) is 2
# The loss value at (2, 0, 9) is 2
# The loss value at (2, 1, 9) is 2
# The loss value at (2, 2, 9) is 2
# The loss value at (0, 3, 9) is 2
# The loss value at (1, 3, 9) is 2
# The loss value at (2, 3, 9) is 2
# The loss value at (3, 0, 9) is 2
# The loss value at (3, 1, 9) is 2
# The loss value at (3, 2, 9) is 2
# The loss value at (3, 3, 9) is 2
# The loss value at (0, 4, 9) is 2
# The loss value at (1, 4, 9) is 2
# The loss value at (2, 4, 9) is 2
# The loss value at (3, 4, 9) is 2
# The loss value at (4, 0, 9) is 2
# The loss value at (4, 1, 9) is 2
# The loss value at (4, 2, 9) is 2
# The loss value at (4, 3, 9) is 2
# The loss value at (4, 4, 9) is 2
# The loss value at (0, 5, 9) is 2
# The loss value at (1, 5, 9) is 2
# The loss value at (2, 5, 9) is 2
# The loss value at (3, 5, 9) is 2
# The loss value at (4, 5, 9) is 2
# The loss value at (5, 0, 9) is 2
# The loss value at (5, 1, 9) is 2
# The loss value at (5, 2, 9) is 2
# The loss value at (5, 3, 9) is 2
# The loss value at (5, 4, 9) is 2
# The loss value at (5, 5, 9) is 2
# The loss value at (0, 6, 9) is 2
# The loss value at (1, 6, 9) is 2
# The loss value at (2, 6, 9) is 2
# The loss value at (3, 6, 9) is 2
# The loss value at (4, 6, 9) is 2
# The loss value at (5, 6, 9) is 2
# The loss value at (6, 0, 9) is 2
# The loss value at (6, 1, 9) is 2
# The loss value at (6, 2, 9) is 2
# The loss value at (6, 3, 9) is 2
# The loss value at (6, 4, 9) is 2
# The loss value at (6, 5, 9) is 2
# The loss value at (6, 6, 9) is 2
# The loss value at (0, 7, 9) is 2
# The loss value at (1, 7, 9) is 2
# The loss value at (2, 7, 9) is 2
# The loss value at (3, 7, 9) is 2
# The loss value at (4, 7, 9) is 2
# The loss value at (5, 7, 9) is 2
# The loss value at (6, 7, 9) is 2
# The loss value at (7, 0, 9) is 2
# The loss value at (7, 1, 9) is 2
# The loss value at (7, 2, 9) is 2
# The loss value at (7, 3, 9) is 2
# The loss value at (7, 4, 9) is 2
# The loss value at (7, 5, 9) is 2
# The loss value at (7, 6, 9) is 2
# The loss value at (7, 7, 9) is 2
# The loss value at (0, 8, 9) is 2
# The loss value at (1, 8, 9) is 2
# The loss value at (2, 8, 9) is 2
# The loss value at (3, 8, 9) is 2
# The loss value at (4, 8, 9) is 2
# The loss value at (5, 8, 9) is 2
# The loss value at (6, 8, 9) is 2
# The loss value at (7, 8, 9) is 2
# The loss value at (8, 0, 9) is 2
# The loss value at (8, 1, 9) is 2
# The loss value at (8, 2, 9) is 2
# The loss value at (8, 3, 9) is 2
# The loss value at (8, 4, 9) is 2
# The loss value at (8, 5, 9) is 2
# The loss value at (8, 6, 9) is 2
# The loss value at (8, 7, 9) is 2
# The loss value at (8, 8, 9) is 2
# The loss value at (0, 9, 0) is 2
# The loss value at (0, 9, 1) is 2
# The loss value at (1, 9, 0) is 2
# The loss value at (1, 9, 1) is 2
# The loss value at (0, 9, 2) is 2
# The loss value at (1, 9, 2) is 2
# The loss value at (2, 9, 0) is 2
# The loss value at (2, 9, 1) is 2
# The loss value at (2, 9, 2) is 2
# The loss value at (0, 9, 3) is 2
# The loss value at (1, 9, 3) is 2
# The loss value at (2, 9, 3) is 2
# The loss value at (3, 9, 0) is 2
# The loss value at (3, 9, 1) is 2
# The loss value at (3, 9, 2) is 2
# The loss value at (3, 9, 3) is 2
# The loss value at (0, 9, 4) is 2
# The loss value at (1, 9, 4) is 2
# The loss value at (2, 9, 4) is 2
# The loss value at (3, 9, 4) is 2
# The loss value at (4, 9, 0) is 2
# The loss value at (4, 9, 1) is 2
# The loss value at (4, 9, 2) is 2
# The loss value at (4, 9, 3) is 2
# The loss value at (4, 9, 4) is 2
# The loss value at (0, 9, 5) is 2
# The loss value at (1, 9, 5) is 2
# The loss value at (2, 9, 5) is 2
# The loss value at (3, 9, 5) is 2
# The loss value at (4, 9, 5) is 2
# The loss value at (5, 9, 0) is 2
# The loss value at (5, 9, 1) is 2
# The loss value at (5, 9, 2) is 2
# The loss value at (5, 9, 3) is 2
# The loss value at (5, 9, 4) is 2
# The loss value at (5, 9, 5) is 2
# The loss value at (0, 9, 6) is 2
# The loss value at (1, 9, 6) is 2
# The loss value at (2, 9, 6) is 2
# The loss value at (3, 9, 6) is 2
# The loss value at (4, 9, 6) is 2
# The loss value at (5, 9, 6) is 2
# The loss value at (6, 9, 0) is 2
# The loss value at (6, 9, 1) is 2
# The loss value at (6, 9, 2) is 2
# The loss value at (6, 9, 3) is 2
# The loss value at (6, 9, 4) is 2
# The loss value at (6, 9, 5) is 2
# The loss value at (6, 9, 6) is 2
# The loss value at (0, 9, 7) is 2
# The loss value at (1, 9, 7) is 2
# The loss value at (2, 9, 7) is 2
# The loss value at (3, 9, 7) is 2
# The loss value at (4, 9, 7) is 2
# The loss value at (5, 9, 7) is 2
# The loss value at (6, 9, 7) is 2
# The loss value at (7, 9, 0) is 2
# The loss value at (7, 9, 1) is 2
# The loss value at (7, 9, 2) is 2
# The loss value at (7, 9, 3) is 2
# The loss value at (7, 9, 4) is 2
# The loss value at (7, 9, 5) is 2
# The loss value at (7, 9, 6) is 2
# The loss value at (7, 9, 7) is 2
# The loss value at (0, 9, 8) is 2
# The loss value at (1, 9, 8) is 2
# The loss value at (2, 9, 8) is 2
# The loss value at (3, 9, 8) is 2
# The loss value at (4, 9, 8) is 2
# The loss value at (5, 9, 8) is 2
# The loss value at (6, 9, 8) is 2
# The loss value at (7, 9, 8) is 2
# The loss value at (8, 9, 0) is 2
# The loss value at (8, 9, 1) is 2
# The loss value at (8, 9, 2) is 2
# The loss value at (8, 9, 3) is 2
# The loss value at (8, 9, 4) is 2
# The loss value at (8, 9, 5) is 2
# The loss value at (8, 9, 6) is 2
# The loss value at (8, 9, 7) is 2
# The loss value at (8, 9, 8) is 2
# The loss value at (0, 9, 9) is 2
# The loss value at (1, 9, 9) is 2
# The loss value at (2, 9, 9) is 2
# The loss value at (3, 9, 9) is 2
# The loss value at (4, 9, 9) is 2
# The loss value at (5, 9, 9) is 2
# The loss value at (6, 9, 9) is 2
# The loss value at (7, 9, 9) is 2
# The loss value at (8, 9, 9) is 2
# The loss value at (9, 0, 0) is 2
# The loss value at (9, 0, 1) is 2
# The loss value at (9, 1, 0) is 2
# The loss value at (9, 1, 1) is 2
# The loss value at (9, 0, 2) is 2
# The loss value at (9, 1, 2) is 2
# The loss value at (9, 2, 0) is 2
# The loss value at (9, 2, 1) is 2
# The loss value at (9, 2, 2) is 2
# The loss value at (9, 0, 3) is 2
# The loss value at (9, 1, 3) is 2
# The loss value at (9, 2, 3) is 2
# The loss value at (9, 3, 0) is 2
# The loss value at (9, 3, 1) is 2
# The loss value at (9, 3, 2) is 2
# The loss value at (9, 3, 3) is 2
# The loss value at (9, 0, 4) is 2
# The loss value at (9, 1, 4) is 2
# The loss value at (9, 2, 4) is 2
# The loss value at (9, 3, 4) is 2
# The loss value at (9, 4, 0) is 2
# The loss value at (9, 4, 1) is 2
# The loss value at (9, 4, 2) is 2
# The loss value at (9, 4, 3) is 2
# The loss value at (9, 4, 4) is 2
# The loss value at (9, 0, 5) is 2
# The loss value at (9, 1, 5) is 2
# The loss value at (9, 2, 5) is 2
# The loss value at (9, 3, 5) is 2
# The loss value at (9, 4, 5) is 2
# The loss value at (9, 5, 0) is 2
# The loss value at (9, 5, 1) is 2
# The loss value at (9, 5, 2) is 2
# The loss value at (9, 5, 3) is 2
# The loss value at (9, 5, 4) is 2
# The loss value at (9, 5, 5) is 2
# The loss value at (9, 0, 6) is 2
# The loss value at (9, 1, 6) is 2
# The loss value at (9, 2, 6) is 2
# The loss value at (9, 3, 6) is 2
# The loss value at (9, 4, 6) is 2
# The loss value at (9, 5, 6) is 2
# The loss value at (9, 6, 0) is 2
# The loss value at (9, 6, 1) is 2
# The loss value at (9, 6, 2) is 2
# The loss value at (9, 6, 3) is 2
# The loss value at (9, 6, 4) is 2
# The loss value at (9, 6, 5) is 2
# The loss value at (9, 6, 6) is 2
# The loss value at (9, 0, 7) is 2
# The loss value at (9, 1, 7) is 2
# The loss value at (9, 2, 7) is 2
# The loss value at (9, 3, 7) is 2
# The loss value at (9, 4, 7) is 2
# The loss value at (9, 5, 7) is 2
# The loss value at (9, 6, 7) is 2
# The loss value at (9, 7, 0) is 2
# The loss value at (9, 7, 1) is 2
# The loss value at (9, 7, 2) is 2
# The loss value at (9, 7, 3) is 2
# The loss value at (9, 7, 4) is 2
# The loss value at (9, 7, 5) is 2
# The loss value at (9, 7, 6) is 2
# The loss value at (9, 7, 7) is 2
# The loss value at (9, 0, 8) is 2
# The loss value at (9, 1, 8) is 2
# The loss value at (9, 2, 8) is 2
# The loss value at (9, 3, 8) is 2
# The loss value at (9, 4, 8) is 2
# The loss value at (9, 5, 8) is 2
# The loss value at (9, 6, 8) is 2
# The loss value at (9, 7, 8) is 2
# The loss value at (9, 8, 0) is 2
# The loss value at (9, 8, 1) is 2
# The loss value at (9, 8, 2) is 2
# The loss value at (9, 8, 3) is 2
# The loss value at (9, 8, 4) is 2
# The loss value at (9, 8, 5) is 2
# The loss value at (9, 8, 6) is 2
# The loss value at (9, 8, 7) is 2
# The loss value at (9, 8, 8) is 2
# The loss value at (9, 0, 9) is 2
# The loss value at (9, 1, 9) is 2
# The loss value at (9, 2, 9) is 2
# The loss value at (9, 3, 9) is 2
# The loss value at (9, 4, 9) is 2
# The loss value at (9, 5, 9) is 2
# The loss value at (9, 6, 9) is 2
# The loss value at (9, 7, 9) is 2
# The loss value at (9, 8, 9) is 2
# The loss value at (9, 9, 0) is 2
# The loss value at (9, 9, 1) is 2
# The loss value at (9, 9, 2) is 2
# The loss value at (9, 9, 3) is 2
# The loss value at (9, 9, 4) is 2
# The loss value at (9, 9, 5) is 2
# The loss value at (9, 9, 6) is 2
# The loss value at (9, 9, 7) is 2
# The loss value at (9, 9, 8) is 2
# The loss value at (9, 9, 9) is 2
# The loss value at (0, 0, 10) is 2
# The loss value at (0, 1, 10) is 2
# The loss value at (1, 0, 10) is 2
# The loss value at (1, 1, 10) is 2
# The loss value at (0, 2, 10) is 2
# The loss value at (1, 2, 10) is 2
# The loss value at (2, 0, 10) is 2
# The loss value at (2, 1, 10) is 2
# The loss value at (2, 2, 10) is 2
# The loss value at (0, 3, 10) is 2
# The loss value at (1, 3, 10) is 2
# The loss value at (2, 3, 10) is 2
# The loss value at (3, 0, 10) is 2
# The loss value at (3, 1, 10) is 2
# The loss value at (3, 2, 10) is 2
# The loss value at (3, 3, 10) is 2
# The loss value at (0, 4, 10) is 2
# The loss value at (1, 4, 10) is 2
# The loss value at (2, 4, 10) is 2
# The loss value at (3, 4, 10) is 2
# The loss value at (4, 0, 10) is 2
# The loss value at (4, 1, 10) is 2
# The loss value at (4, 2, 10) is 2
# The loss value at (4, 3, 10) is 2
# The loss value at (4, 4, 10) is 2
# The loss value at (0, 5, 10) is 2
# The loss value at (1, 5, 10) is 2
# The loss value at (2, 5, 10) is 2
# The loss value at (3, 5, 10) is 2
# The loss value at (4, 5, 10) is 2
# The loss value at (5, 0, 10) is 2
# The loss value at (5, 1, 10) is 2
# The loss value at (5, 2, 10) is 2
# The loss value at (5, 3, 10) is 2
# The loss value at (5, 4, 10) is 2
# The loss value at (5, 5, 10) is 2
# The loss value at (0, 6, 10) is 2
# The loss value at (1, 6, 10) is 2
# The loss value at (2, 6, 10) is 2
# The loss value at (3, 6, 10) is 2
# The loss value at (4, 6, 10) is 2
# The loss value at (5, 6, 10) is 2
# The loss value at (6, 0, 10) is 2
# The loss value at (6, 1, 10) is 2
# The loss value at (6, 2, 10) is 2
# The loss value at (6, 3, 10) is 2
# The loss value at (6, 4, 10) is 2
# The loss value at (6, 5, 10) is 2
# The loss value at (6, 6, 10) is 2
# The loss value at (0, 7, 10) is 2
# The loss value at (1, 7, 10) is 2
# The loss value at (2, 7, 10) is 2
# The loss value at (3, 7, 10) is 2
# The loss value at (4, 7, 10) is 2
# The loss value at (5, 7, 10) is 2
# The loss value at (6, 7, 10) is 2
# The loss value at (7, 0, 10) is 2
# The loss value at (7, 1, 10) is 2
# The loss value at (7, 2, 10) is 2
# The loss value at (7, 3, 10) is 2
# The loss value at (7, 4, 10) is 2
# The loss value at (7, 5, 10) is 2
# The loss value at (7, 6, 10) is 2
# The loss value at (7, 7, 10) is 2
# The loss value at (0, 8, 10) is 2
# The loss value at (1, 8, 10) is 2
# The loss value at (2, 8, 10) is 2
# The loss value at (3, 8, 10) is 2
# The loss value at (4, 8, 10) is 2
# The loss value at (5, 8, 10) is 2
# The loss value at (6, 8, 10) is 2
# The loss value at (7, 8, 10) is 2
# The loss value at (8, 0, 10) is 2
# The loss value at (8, 1, 10) is 2
# The loss value at (8, 2, 10) is 2
# The loss value at (8, 3, 10) is 2
# The loss value at (8, 4, 10) is 2
# The loss value at (8, 5, 10) is 2
# The loss value at (8, 6, 10) is 2
# The loss value at (8, 7, 10) is 2
# The loss value at (8, 8, 10) is 2
# The loss value at (0, 9, 10) is 2
# The loss value at (1, 9, 10) is 2
# The loss value at (2, 9, 10) is 2
# The loss value at (3, 9, 10) is 2
# The loss value at (4, 9, 10) is 2
# The loss value at (5, 9, 10) is 2
# The loss value at (6, 9, 10) is 2
# The loss value at (7, 9, 10) is 2
# The loss value at (8, 9, 10) is 2
# The loss value at (9, 0, 10) is 2
# The loss value at (9, 1, 10) is 2
# The loss value at (9, 2, 10) is 2
# The loss value at (9, 3, 10) is 2
# The loss value at (9, 4, 10) is 2
# The loss value at (9, 5, 10) is 2
# The loss value at (9, 6, 10) is 2
# The loss value at (9, 7, 10) is 2
# The loss value at (9, 8, 10) is 2
# The loss value at (9, 9, 10) is 2
# The loss value at (0, 10, 0) is 2
# The loss value at (0, 10, 1) is 2
# The loss value at (1, 10, 0) is 2
# The loss value at (1, 10, 1) is 2
# The loss value at (0, 10, 2) is 2
# The loss value at (1, 10, 2) is 2
# The loss value at (2, 10, 0) is 2
# The loss value at (2, 10, 1) is 2
# The loss value at (2, 10, 2) is 2
# The loss value at (0, 10, 3) is 2
# The loss value at (1, 10, 3) is 2
# The loss value at (2, 10, 3) is 2
# The loss value at (3, 10, 0) is 2
# The loss value at (3, 10, 1) is 2
# The loss value at (3, 10, 2) is 2
# The loss value at (3, 10, 3) is 2
# The loss value at (0, 10, 4) is 2
# The loss value at (1, 10, 4) is 2
# The loss value at (2, 10, 4) is 2
# The loss value at (3, 10, 4) is 2
# The loss value at (4, 10, 0) is 2
# The loss value at (4, 10, 1) is 2
# The loss value at (4, 10, 2) is 2
# The loss value at (4, 10, 3) is 2
# The loss value at (4, 10, 4) is 2
# The loss value at (0, 10, 5) is 2
# The loss value at (1, 10, 5) is 2
# The loss value at (2, 10, 5) is 2
# The loss value at (3, 10, 5) is 2
# The loss value at (4, 10, 5) is 2
# The loss value at (5, 10, 0) is 2
# The loss value at (5, 10, 1) is 2
# The loss value at (5, 10, 2) is 2
# The loss value at (5, 10, 3) is 2
# The loss value at (5, 10, 4) is 2
# The loss value at (5, 10, 5) is 2
# The loss value at (0, 10, 6) is 2
# The loss value at (1, 10, 6) is 2
# The loss value at (2, 10, 6) is 2
# The loss value at (3, 10, 6) is 2
# The loss value at (4, 10, 6) is 2
# The loss value at (5, 10, 6) is 2
# The loss value at (6, 10, 0) is 2
# The loss value at (6, 10, 1) is 2
# The loss value at (6, 10, 2) is 2
# The loss value at (6, 10, 3) is 2
# The loss value at (6, 10, 4) is 2
# The loss value at (6, 10, 5) is 2
# The loss value at (6, 10, 6) is 2
# The loss value at (0, 10, 7) is 2
# The loss value at (1, 10, 7) is 2
# The loss value at (2, 10, 7) is 2
# The loss value at (3, 10, 7) is 2
# The loss value at (4, 10, 7) is 2
# The loss value at (5, 10, 7) is 2
# The loss value at (6, 10, 7) is 2
# The loss value at (7, 10, 0) is 2
# The loss value at (7, 10, 1) is 2
# The loss value at (7, 10, 2) is 2
# The loss value at (7, 10, 3) is 2
# The loss value at (7, 10, 4) is 2
# The loss value at (7, 10, 5) is 2
# The loss value at (7, 10, 6) is 2
# The loss value at (7, 10, 7) is 2
# The loss value at (0, 10, 8) is 2
# The loss value at (1, 10, 8) is 2
# The loss value at (2, 10, 8) is 2
# The loss value at (3, 10, 8) is 2
# The loss value at (4, 10, 8) is 2
# The loss value at (5, 10, 8) is 2
# The loss value at (6, 10, 8) is 2
# The loss value at (7, 10, 8) is 2
# The loss value at (8, 10, 0) is 2
# The loss value at (8, 10, 1) is 2
# The loss value at (8, 10, 2) is 2
# The loss value at (8, 10, 3) is 2
# The loss value at (8, 10, 4) is 2
# The loss value at (8, 10, 5) is 2
# The loss value at (8, 10, 6) is 2
# The loss value at (8, 10, 7) is 2
# The loss value at (8, 10, 8) is 2
# The loss value at (0, 10, 9) is 2
# The loss value at (1, 10, 9) is 2
# The loss value at (2, 10, 9) is 2
# The loss value at (3, 10, 9) is 2
# The loss value at (4, 10, 9) is 2
# The loss value at (5, 10, 9) is 2
# The loss value at (6, 10, 9) is 2
# The loss value at (7, 10, 9) is 2
# The loss value at (8, 10, 9) is 2
# The loss value at (9, 10, 0) is 2
# The loss value at (9, 10, 1) is 2
# The loss value at (9, 10, 2) is 2
# The loss value at (9, 10, 3) is 2
# The loss value at (9, 10, 4) is 2
# The loss value at (9, 10, 5) is 2
# The loss value at (9, 10, 6) is 2
# The loss value at (9, 10, 7) is 2
# The loss value at (9, 10, 8) is 2
# The loss value at (9, 10, 9) is 2
# The loss value at (0, 10, 10) is 2
# The loss value at (1, 10, 10) is 2
# The loss value at (2, 10, 10) is 2
# The loss value at (3, 10, 10) is 2
# The loss value at (4, 10, 10) is 2
# The loss value at (5, 10, 10) is 2
# The loss value at (6, 10, 10) is 2
# The loss value at (7, 10, 10) is 2
# The loss value at (8, 10, 10) is 2
# The loss value at (9, 10, 10) is 2
# The loss value at (10, 0, 0) is 2
# The loss value at (10, 0, 1) is 2
# The loss value at (10, 1, 0) is 2
# The loss value at (10, 1, 1) is 2
# The loss value at (10, 0, 2) is 2
# The loss value at (10, 1, 2) is 2
# The loss value at (10, 2, 0) is 2
# The loss value at (10, 2, 1) is 2
# The loss value at (10, 2, 2) is 2
# The loss value at (10, 0, 3) is 2
# The loss value at (10, 1, 3) is 2
# The loss value at (10, 2, 3) is 2
# The loss value at (10, 3, 0) is 2
# The loss value at (10, 3, 1) is 2
# The loss value at (10, 3, 2) is 2
# The loss value at (10, 3, 3) is 2
# The loss value at (10, 0, 4) is 2
# The loss value at (10, 1, 4) is 2
# The loss value at (10, 2, 4) is 2
# The loss value at (10, 3, 4) is 2
# The loss value at (10, 4, 0) is 2
# The loss value at (10, 4, 1) is 2
# The loss value at (10, 4, 2) is 2
# The loss value at (10, 4, 3) is 2
# The loss value at (10, 4, 4) is 2
# The loss value at (10, 0, 5) is 2
# The loss value at (10, 1, 5) is 2
# The loss value at (10, 2, 5) is 2
# The loss value at (10, 3, 5) is 2
# The loss value at (10, 4, 5) is 2
# The loss value at (10, 5, 0) is 2
# The loss value at (10, 5, 1) is 2
# The loss value at (10, 5, 2) is 2
# The loss value at (10, 5, 3) is 2
# The loss value at (10, 5, 4) is 2
# The loss value at (10, 5, 5) is 2
# The loss value at (10, 0, 6) is 2
# The loss value at (10, 1, 6) is 2
# The loss value at (10, 2, 6) is 2
# The loss value at (10, 3, 6) is 2
# The loss value at (10, 4, 6) is 2
# The loss value at (10, 5, 6) is 2
# The loss value at (10, 6, 0) is 2
# The loss value at (10, 6, 1) is 2
# The loss value at (10, 6, 2) is 2
# The loss value at (10, 6, 3) is 2
# The loss value at (10, 6, 4) is 2
# The loss value at (10, 6, 5) is 2
# The loss value at (10, 6, 6) is 2
# The loss value at (10, 0, 7) is 2
# The loss value at (10, 1, 7) is 2
# The loss value at (10, 2, 7) is 2
# The loss value at (10, 3, 7) is 2
# The loss value at (10, 4, 7) is 2
# The loss value at (10, 5, 7) is 2
# The loss value at (10, 6, 7) is 2
# The loss value at (10, 7, 0) is 2
# The loss value at (10, 7, 1) is 2
# The loss value at (10, 7, 2) is 2
# The loss value at (10, 7, 3) is 2
# The loss value at (10, 7, 4) is 2
# The loss value at (10, 7, 5) is 2
# The loss value at (10, 7, 6) is 2
# The loss value at (10, 7, 7) is 2
# The loss value at (10, 0, 8) is 2
# The loss value at (10, 1, 8) is 2
# The loss value at (10, 2, 8) is 2
# The loss value at (10, 3, 8) is 2
# The loss value at (10, 4, 8) is 2
# The loss value at (10, 5, 8) is 2
# The loss value at (10, 6, 8) is 2
# The loss value at (10, 7, 8) is 2
# The loss value at (10, 8, 0) is 2
# The loss value at (10, 8, 1) is 2
# The loss value at (10, 8, 2) is 2
# The loss value at (10, 8, 3) is 2
# The loss value at (10, 8, 4) is 2
# The loss value at (10, 8, 5) is 2
# The loss value at (10, 8, 6) is 2
# The loss value at (10, 8, 7) is 2
# The loss value at (10, 8, 8) is 2
# The loss value at (10, 0, 9) is 2
# The loss value at (10, 1, 9) is 2
# The loss value at (10, 2, 9) is 2
# The loss value at (10, 3, 9) is 2
# The loss value at (10, 4, 9) is 2
# The loss value at (10, 5, 9) is 2
# The loss value at (10, 6, 9) is 2
# The loss value at (10, 7, 9) is 2
# The loss value at (10, 8, 9) is 2
# The loss value at (10, 9, 0) is 2
# The loss value at (10, 9, 1) is 2
# The loss value at (10, 9, 2) is 2
# The loss value at (10, 9, 3) is 2
# The loss value at (10, 9, 4) is 2
# The loss value at (10, 9, 5) is 2
# The loss value at (10, 9, 6) is 2
# The loss value at (10, 9, 7) is 2
# The loss value at (10, 9, 8) is 2
# The loss value at (10, 9, 9) is 2
# The loss value at (10, 0, 10) is 2
# The loss value at (10, 1, 10) is 2
# The loss value at (10, 2, 10) is 2
# The loss value at (10, 3, 10) is 2
# The loss value at (10, 4, 10) is 2
# The loss value at (10, 5, 10) is 2
# The loss value at (10, 6, 10) is 2
# The loss value at (10, 7, 10) is 2
# The loss value at (10, 8, 10) is 2
# The loss value at (10, 9, 10) is 2
# The loss value at (10, 10, 0) is 2
# The loss value at (10, 10, 1) is 2
# The loss value at (10, 10, 2) is 2
# The loss value at (10, 10, 3) is 2
# The loss value at (10, 10, 4) is 2
# The loss value at (10, 10, 5) is 2
# The loss value at (10, 10, 6) is 2
# The loss value at (10, 10, 7) is 2
# The loss value at (10, 10, 8) is 2
# The loss value at (10, 10, 9) is 2
# The loss value at (10, 10, 10) is 2
# The loss value at (0, 0, 11) is 2
# The loss value at (0, 1, 11) is 2
# The loss value at (1, 0, 11) is 2
# The loss value at (1, 1, 11) is 2
# The loss value at (0, 2, 11) is 2
# The loss value at (1, 2, 11) is 2
# The loss value at (2, 0, 11) is 2
# The loss value at (2, 1, 11) is 2
# The loss value at (2, 2, 11) is 2
# The loss value at (0, 3, 11) is 2
# The loss value at (1, 3, 11) is 2
# The loss value at (2, 3, 11) is 2
# The loss value at (3, 0, 11) is 2
# The loss value at (3, 1, 11) is 2
# The loss value at (3, 2, 11) is 2
# The loss value at (3, 3, 11) is 2
# The loss value at (0, 4, 11) is 2
# The loss value at (1, 4, 11) is 2
# The loss value at (2, 4, 11) is 2
# The loss value at (3, 4, 11) is 2
# The loss value at (4, 0, 11) is 2
# The loss value at (4, 1, 11) is 2
# The loss value at (4, 2, 11) is 2
# The loss value at (4, 3, 11) is 2
# The loss value at (4, 4, 11) is 2
# The loss value at (0, 5, 11) is 2
# The loss value at (1, 5, 11) is 2
# The loss value at (2, 5, 11) is 2
# The loss value at (3, 5, 11) is 2
# The loss value at (4, 5, 11) is 2
# The loss value at (5, 0, 11) is 2
# The loss value at (5, 1, 11) is 2
# The loss value at (5, 2, 11) is 2
# The loss value at (5, 3, 11) is 2
# The loss value at (5, 4, 11) is 2
# The loss value at (5, 5, 11) is 2
# The loss value at (0, 6, 11) is 2
# The loss value at (1, 6, 11) is 2
# The loss value at (2, 6, 11) is 2
# The loss value at (3, 6, 11) is 2
# The loss value at (4, 6, 11) is 2
# The loss value at (5, 6, 11) is 2
# The loss value at (6, 0, 11) is 2
# The loss value at (6, 1, 11) is 2
# The loss value at (6, 2, 11) is 2
# The loss value at (6, 3, 11) is 2
# The loss value at (6, 4, 11) is 2
# The loss value at (6, 5, 11) is 2
# The loss value at (6, 6, 11) is 2
# The loss value at (0, 7, 11) is 2
# The loss value at (1, 7, 11) is 2
# The loss value at (2, 7, 11) is 2
# The loss value at (3, 7, 11) is 2
# The loss value at (4, 7, 11) is 2
# The loss value at (5, 7, 11) is 2
# The loss value at (6, 7, 11) is 2
# The loss value at (7, 0, 11) is 2
# The loss value at (7, 1, 11) is 2
# The loss value at (7, 2, 11) is 2
# The loss value at (7, 3, 11) is 2
# The loss value at (7, 4, 11) is 2
# The loss value at (7, 5, 11) is 2
# The loss value at (7, 6, 11) is 2
# The loss value at (7, 7, 11) is 2
# The loss value at (0, 8, 11) is 2
# The loss value at (1, 8, 11) is 2
# The loss value at (2, 8, 11) is 2
# The loss value at (3, 8, 11) is 2
# The loss value at (4, 8, 11) is 2
# The loss value at (5, 8, 11) is 2
# The loss value at (6, 8, 11) is 2
# The loss value at (7, 8, 11) is 2
# The loss value at (8, 0, 11) is 2
# The loss value at (8, 1, 11) is 2
# The loss value at (8, 2, 11) is 2
# The loss value at (8, 3, 11) is 2
# The loss value at (8, 4, 11) is 2
# The loss value at (8, 5, 11) is 2
# The loss value at (8, 6, 11) is 2
# The loss value at (8, 7, 11) is 2
# The loss value at (8, 8, 11) is 2
# The loss value at (0, 9, 11) is 2
# The loss value at (1, 9, 11) is 2
# The loss value at (2, 9, 11) is 2
# The loss value at (3, 9, 11) is 2
# The loss value at (4, 9, 11) is 2
# The loss value at (5, 9, 11) is 2
# The loss value at (6, 9, 11) is 2
# The loss value at (7, 9, 11) is 2
# The loss value at (8, 9, 11) is 2
# The loss value at (9, 0, 11) is 2
# The loss value at (9, 1, 11) is 2
# The loss value at (9, 2, 11) is 2
# The loss value at (9, 3, 11) is 2
# The loss value at (9, 4, 11) is 2
# The loss value at (9, 5, 11) is 2
# The loss value at (9, 6, 11) is 2
# The loss value at (9, 7, 11) is 2
# The loss value at (9, 8, 11) is 2
# The loss value at (9, 9, 11) is 2
# The loss value at (0, 10, 11) is 2
# The loss value at (1, 10, 11) is 2
# The loss value at (2, 10, 11) is 2
# The loss value at (3, 10, 11) is 2
# ...
# The loss value at (18, 19, 6) is 2
# The loss value at (18, 19, 7) is 2
# The loss value at (18, 19, 8) is 2
# The loss value at (18, 19, 9) is 2
# The loss value at (18, 19, 10) is 2
# The loss value at (18, 19, 11) is 2
# The loss value at (18, 19, 12) is 2
# The loss value at (18, 19, 13) is 2
# The loss value at (18, 19, 14) is 2
# The loss value at (18, 19, 15) is 2
# The loss value at (18, 19, 16) is 2
# The loss value at (18, 19, 17) is 2
# The loss value at (18, 19, 18) is 2
# The loss value at (0, 19, 19) is 2
# The loss value at (1, 19, 19) is 2
# The loss value at (2, 19, 19) is 2
# The loss value at (3, 19, 19) is 2
# The loss value at (4, 19, 19) is 2
# The loss value at (5, 19, 19) is 2
# The loss value at (6, 19, 19) is 2
# The loss value at (7, 19, 19) is 2
# The loss value at (8, 19, 19) is 2
# The loss value at (9, 19, 19) is 2
# The loss value at (10, 19, 19) is 2
# The loss value at (11, 19, 19) is 2
# The loss value at (12, 19, 19) is 2
# The loss value at (13, 19, 19) is 2
# The loss value at (14, 19, 19) is 2
# The loss value at (15, 19, 19) is 2
# The loss value at (16, 19, 19) is 2
# The loss value at (17, 19, 19) is 2
# The loss value at (18, 19, 19) is 2
# The loss value at (19, 0, 0) is 2
# The loss value at (19, 0, 1) is 2
# The loss value at (19, 1, 0) is 2
# The loss value at (19, 1, 1) is 2
# The loss value at (19, 0, 2) is 2
# The loss value at (19, 1, 2) is 2
# The loss value at (19, 2, 0) is 2
# The loss value at (19, 2, 1) is 2
# The loss value at (19, 2, 2) is 2
# The loss value at (19, 0, 3) is 2
# The loss value at (19, 1, 3) is 2
# The loss value at (19, 2, 3) is 2
# The loss value at (19, 3, 0) is 2
# The loss value at (19, 3, 1) is 2
# The loss value at (19, 3, 2) is 2
# The loss value at (19, 3, 3) is 2
# The loss value at (19, 0, 4) is 2
# The loss value at (19, 1, 4) is 2
# The loss value at (19, 2, 4) is 2
# The loss value at (19, 3, 4) is 2
# The loss value at (19, 4, 0) is 2
# The loss value at (19, 4, 1) is 2
# The loss value at (19, 4, 2) is 2
# The loss value at (19, 4, 3) is 2
# The loss value at (19, 4, 4) is 2
# The loss value at (19, 0, 5) is 2
# The loss value at (19, 1, 5) is 2
# The loss value at (19, 2, 5) is 2
# The loss value at (19, 3, 5) is 2
# The loss value at (19, 4, 5) is 2
# The loss value at (19, 5, 0) is 2
# The loss value at (19, 5, 1) is 2
# The loss value at (19, 5, 2) is 2
# The loss value at (19, 5, 3) is 2
# The loss value at (19, 5, 4) is 2
# The loss value at (19, 5, 5) is 2
# The loss value at (19, 0, 6) is 2
# The loss value at (19, 1, 6) is 2
# The loss value at (19, 2, 6) is 2
# The loss value at (19, 3, 6) is 2
# The loss value at (19, 4, 6) is 2
# The loss value at (19, 5, 6) is 2
# The loss value at (19, 6, 0) is 2
# The loss value at (19, 6, 1) is 2
# The loss value at (19, 6, 2) is 2
# The loss value at (19, 6, 3) is 2
# The loss value at (19, 6, 4) is 2
# The loss value at (19, 6, 5) is 2
# The loss value at (19, 6, 6) is 2
# The loss value at (19, 0, 7) is 2
# The loss value at (19, 1, 7) is 2
# The loss value at (19, 2, 7) is 2
# The loss value at (19, 3, 7) is 2
# The loss value at (19, 4, 7) is 2
# The loss value at (19, 5, 7) is 2
# The loss value at (19, 6, 7) is 2
# The loss value at (19, 7, 0) is 2
# The loss value at (19, 7, 1) is 2
# The loss value at (19, 7, 2) is 2
# The loss value at (19, 7, 3) is 2
# The loss value at (19, 7, 4) is 2
# The loss value at (19, 7, 5) is 2
# The loss value at (19, 7, 6) is 2
# The loss value at (19, 7, 7) is 2
# The loss value at (19, 0, 8) is 2
# The loss value at (19, 1, 8) is 2
# The loss value at (19, 2, 8) is 2
# The loss value at (19, 3, 8) is 2
# The loss value at (19, 4, 8) is 2
# The loss value at (19, 5, 8) is 2
# The loss value at (19, 6, 8) is 2
# The loss value at (19, 7, 8) is 2
# The loss value at (19, 8, 0) is 2
# The loss value at (19, 8, 1) is 2
# The loss value at (19, 8, 2) is 2
# The loss value at (19, 8, 3) is 2
# The loss value at (19, 8, 4) is 2
# The loss value at (19, 8, 5) is 2
# The loss value at (19, 8, 6) is 2
# The loss value at (19, 8, 7) is 2
# The loss value at (19, 8, 8) is 2
# The loss value at (19, 0, 9) is 2
# The loss value at (19, 1, 9) is 2
# The loss value at (19, 2, 9) is 2
# The loss value at (19, 3, 9) is 2
# The loss value at (19, 4, 9) is 2
# The loss value at (19, 5, 9) is 2
# The loss value at (19, 6, 9) is 2
# The loss value at (19, 7, 9) is 2
# The loss value at (19, 8, 9) is 2
# The loss value at (19, 9, 0) is 2
# The loss value at (19, 9, 1) is 2
# The loss value at (19, 9, 2) is 2
# The loss value at (19, 9, 3) is 2
# The loss value at (19, 9, 4) is 2
# The loss value at (19, 9, 5) is 2
# The loss value at (19, 9, 6) is 2
# The loss value at (19, 9, 7) is 2
# The loss value at (19, 9, 8) is 2
# The loss value at (19, 9, 9) is 2
# The loss value at (19, 0, 10) is 2
# The loss value at (19, 1, 10) is 2
# The loss value at (19, 2, 10) is 2
# The loss value at (19, 3, 10) is 2
# The loss value at (19, 4, 10) is 2
# The loss value at (19, 5, 10) is 2
# The loss value at (19, 6, 10) is 2
# The loss value at (19, 7, 10) is 2
# The loss value at (19, 8, 10) is 2
# The loss value at (19, 9, 10) is 2
# The loss value at (19, 10, 0) is 2
# The loss value at (19, 10, 1) is 2
# The loss value at (19, 10, 2) is 2
# The loss value at (19, 10, 3) is 2
# The loss value at (19, 10, 4) is 2
# The loss value at (19, 10, 5) is 2
# The loss value at (19, 10, 6) is 2
# The loss value at (19, 10, 7) is 2
# The loss value at (19, 10, 8) is 2
# The loss value at (19, 10, 9) is 2
# The loss value at (19, 10, 10) is 2
# The loss value at (19, 0, 11) is 2
# The loss value at (19, 1, 11) is 2
# The loss value at (19, 2, 11) is 2
# The loss value at (19, 3, 11) is 2
# The loss value at (19, 4, 11) is 2
# The loss value at (19, 5, 11) is 2
# The loss value at (19, 6, 11) is 2
# The loss value at (19, 7, 11) is 2
# The loss value at (19, 8, 11) is 2
# The loss value at (19, 9, 11) is 2
# The loss value at (19, 10, 11) is 2
# The loss value at (19, 11, 0) is 2
# The loss value at (19, 11, 1) is 2
# The loss value at (19, 11, 2) is 2
# The loss value at (19, 11, 3) is 2
# The loss value at (19, 11, 4) is 2
# The loss value at (19, 11, 5) is 2
# The loss value at (19, 11, 6) is 2
# The loss value at (19, 11, 7) is 2
# The loss value at (19, 11, 8) is 2
# The loss value at (19, 11, 9) is 2
# The loss value at (19, 11, 10) is 2
# The loss value at (19, 11, 11) is 2
# The loss value at (19, 0, 12) is 2
# The loss value at (19, 1, 12) is 2
# The loss value at (19, 2, 12) is 2
# The loss value at (19, 3, 12) is 2
# The loss value at (19, 4, 12) is 2
# The loss value at (19, 5, 12) is 2
# The loss value at (19, 6, 12) is 2
# The loss value at (19, 7, 12) is 2
# The loss value at (19, 8, 12) is 2
# The loss value at (19, 9, 12) is 2
# The loss value at (19, 10, 12) is 2
# The loss value at (19, 11, 12) is 2
# The loss value at (19, 12, 0) is 2
# The loss value at (19, 12, 1) is 2
# The loss value at (19, 12, 2) is 2
# The loss value at (19, 12, 3) is 2
# The loss value at (19, 12, 4) is 2
# The loss value at (19, 12, 5) is 2
# The loss value at (19, 12, 6) is 2
# The loss value at (19, 12, 7) is 2
# The loss value at (19, 12, 8) is 2
# The loss value at (19, 12, 9) is 2
# The loss value at (19, 12, 10) is 2
# The loss value at (19, 12, 11) is 2
# The loss value at (19, 12, 12) is 2
# The loss value at (19, 0, 13) is 2
# The loss value at (19, 1, 13) is 2
# The loss value at (19, 2, 13) is 2
# The loss value at (19, 3, 13) is 2
# The loss value at (19, 4, 13) is 2
# The loss value at (19, 5, 13) is 2
# The loss value at (19, 6, 13) is 2
# The loss value at (19, 7, 13) is 2
# The loss value at (19, 8, 13) is 2
# The loss value at (19, 9, 13) is 2
# The loss value at (19, 10, 13) is 2
# The loss value at (19, 11, 13) is 2
# The loss value at (19, 12, 13) is 2
# The loss value at (19, 13, 0) is 2
# The loss value at (19, 13, 1) is 2
# The loss value at (19, 13, 2) is 2
# The loss value at (19, 13, 3) is 2
# The loss value at (19, 13, 4) is 2
# The loss value at (19, 13, 5) is 2
# The loss value at (19, 13, 6) is 2
# The loss value at (19, 13, 7) is 2
# The loss value at (19, 13, 8) is 2
# The loss value at (19, 13, 9) is 2
# The loss value at (19, 13, 10) is 2
# The loss value at (19, 13, 11) is 2
# The loss value at (19, 13, 12) is 2
# The loss value at (19, 13, 13) is 2
# The loss value at (19, 0, 14) is 2
# The loss value at (19, 1, 14) is 2
# The loss value at (19, 2, 14) is 2
# The loss value at (19, 3, 14) is 2
# The loss value at (19, 4, 14) is 2
# The loss value at (19, 5, 14) is 2
# The loss value at (19, 6, 14) is 2
# The loss value at (19, 7, 14) is 2
# The loss value at (19, 8, 14) is 2
# The loss value at (19, 9, 14) is 2
# The loss value at (19, 10, 14) is 2
# The loss value at (19, 11, 14) is 2
# The loss value at (19, 12, 14) is 2
# The loss value at (19, 13, 14) is 2
# The loss value at (19, 14, 0) is 2
# The loss value at (19, 14, 1) is 2
# The loss value at (19, 14, 2) is 2
# The loss value at (19, 14, 3) is 2
# The loss value at (19, 14, 4) is 2
# The loss value at (19, 14, 5) is 2
# The loss value at (19, 14, 6) is 2
# The loss value at (19, 14, 7) is 2
# The loss value at (19, 14, 8) is 2
# The loss value at (19, 14, 9) is 2
# The loss value at (19, 14, 10) is 2
# The loss value at (19, 14, 11) is 2
# The loss value at (19, 14, 12) is 2
# The loss value at (19, 14, 13) is 2
# The loss value at (19, 14, 14) is 2
# The loss value at (19, 0, 15) is 2
# The loss value at (19, 1, 15) is 2
# The loss value at (19, 2, 15) is 2
# The loss value at (19, 3, 15) is 2
# The loss value at (19, 4, 15) is 2
# The loss value at (19, 5, 15) is 2
# The loss value at (19, 6, 15) is 2
# The loss value at (19, 7, 15) is 2
# The loss value at (19, 8, 15) is 2
# The loss value at (19, 9, 15) is 2
# The loss value at (19, 10, 15) is 2
# The loss value at (19, 11, 15) is 2
# The loss value at (19, 12, 15) is 2
# The loss value at (19, 13, 15) is 2
# The loss value at (19, 14, 15) is 2
# The loss value at (19, 15, 0) is 2
# The loss value at (19, 15, 1) is 2
# The loss value at (19, 15, 2) is 2
# The loss value at (19, 15, 3) is 2
# The loss value at (19, 15, 4) is 2
# The loss value at (19, 15, 5) is 2
# The loss value at (19, 15, 6) is 2
# The loss value at (19, 15, 7) is 2
# The loss value at (19, 15, 8) is 2
# The loss value at (19, 15, 9) is 2
# The loss value at (19, 15, 10) is 2
# The loss value at (19, 15, 11) is 2
# The loss value at (19, 15, 12) is 2
# The loss value at (19, 15, 13) is 2
# The loss value at (19, 15, 14) is 2
# The loss value at (19, 15, 15) is 2
# The loss value at (19, 0, 16) is 2
# The loss value at (19, 1, 16) is 2
# The loss value at (19, 2, 16) is 2
# The loss value at (19, 3, 16) is 2
# The loss value at (19, 4, 16) is 2
# The loss value at (19, 5, 16) is 2
# The loss value at (19, 6, 16) is 2
# The loss value at (19, 7, 16) is 2
# The loss value at (19, 8, 16) is 2
# The loss value at (19, 9, 16) is 2
# The loss value at (19, 10, 16) is 2
# The loss value at (19, 11, 16) is 2
# The loss value at (19, 12, 16) is 2
# The loss value at (19, 13, 16) is 2
# The loss value at (19, 14, 16) is 2
# The loss value at (19, 15, 16) is 2
# The loss value at (19, 16, 0) is 2
# The loss value at (19, 16, 1) is 2
# The loss value at (19, 16, 2) is 2
# The loss value at (19, 16, 3) is 2
# The loss value at (19, 16, 4) is 2
# The loss value at (19, 16, 5) is 2
# The loss value at (19, 16, 6) is 2
# The loss value at (19, 16, 7) is 2
# The loss value at (19, 16, 8) is 2
# The loss value at (19, 16, 9) is 2
# The loss value at (19, 16, 10) is 2
# The loss value at (19, 16, 11) is 2
# The loss value at (19, 16, 12) is 2
# The loss value at (19, 16, 13) is 2
# The loss value at (19, 16, 14) is 2
# The loss value at (19, 16, 15) is 2
# The loss value at (19, 16, 16) is 2
# The loss value at (19, 0, 17) is 2
# The loss value at (19, 1, 17) is 2
# The loss value at (19, 2, 17) is 2
# The loss value at (19, 3, 17) is 2
# The loss value at (19, 4, 17) is 2
# The loss value at (19, 5, 17) is 2
# The loss value at (19, 6, 17) is 2
# The loss value at (19, 7, 17) is 2
# The loss value at (19, 8, 17) is 2
# The loss value at (19, 9, 17) is 2
# The loss value at (19, 10, 17) is 2
# The loss value at (19, 11, 17) is 2
# The loss value at (19, 12, 17) is 2
# The loss value at (19, 13, 17) is 2
# The loss value at (19, 14, 17) is 2
# The loss value at (19, 15, 17) is 2
# The loss value at (19, 16, 17) is 2
# The loss value at (19, 17, 0) is 2
# The loss value at (19, 17, 1) is 2
# The loss value at (19, 17, 2) is 2
# The loss value at (19, 17, 3) is 2
# The loss value at (19, 17, 4) is 2
# The loss value at (19, 17, 5) is 2
# The loss value at (19, 17, 6) is 2
# The loss value at (19, 17, 7) is 2
# The loss value at (19, 17, 8) is 2
# The loss value at (19, 17, 9) is 2
# The loss value at (19, 17, 10) is 2
# The loss value at (19, 17, 11) is 2
# The loss value at (19, 17, 12) is 2
# The loss value at (19, 17, 13) is 2
# The loss value at (19, 17, 14) is 2
# The loss value at (19, 17, 15) is 2
# The loss value at (19, 17, 16) is 2
# The loss value at (19, 17, 17) is 2
# The loss value at (19, 0, 18) is 2
# The loss value at (19, 1, 18) is 2
# The loss value at (19, 2, 18) is 2
# The loss value at (19, 3, 18) is 2
# The loss value at (19, 4, 18) is 2
# The loss value at (19, 5, 18) is 2
# The loss value at (19, 6, 18) is 2
# The loss value at (19, 7, 18) is 2
# The loss value at (19, 8, 18) is 2
# The loss value at (19, 9, 18) is 2
# The loss value at (19, 10, 18) is 2
# The loss value at (19, 11, 18) is 2
# The loss value at (19, 12, 18) is 2
# The loss value at (19, 13, 18) is 2
# The loss value at (19, 14, 18) is 2
# The loss value at (19, 15, 18) is 2
# The loss value at (19, 16, 18) is 2
# The loss value at (19, 17, 18) is 2
# The loss value at (19, 18, 0) is 2
# The loss value at (19, 18, 1) is 2
# The loss value at (19, 18, 2) is 2
# The loss value at (19, 18, 3) is 2
# The loss value at (19, 18, 4) is 2
# The loss value at (19, 18, 5) is 2
# The loss value at (19, 18, 6) is 2
# The loss value at (19, 18, 7) is 2
# The loss value at (19, 18, 8) is 2
# The loss value at (19, 18, 9) is 2
# The loss value at (19, 18, 10) is 2
# The loss value at (19, 18, 11) is 2
# The loss value at (19, 18, 12) is 2
# The loss value at (19, 18, 13) is 2
# The loss value at (19, 18, 14) is 2
# The loss value at (19, 18, 15) is 2
# The loss value at (19, 18, 16) is 2
# The loss value at (19, 18, 17) is 2
# The loss value at (19, 18, 18) is 2
# The loss value at (19, 0, 19) is 2
# The loss value at (19, 1, 19) is 2
# The loss value at (19, 2, 19) is 2
# The loss value at (19, 3, 19) is 2
# The loss value at (19, 4, 19) is 2
# The loss value at (19, 5, 19) is 2
# The loss value at (19, 6, 19) is 2
# The loss value at (19, 7, 19) is 2
# The loss value at (19, 8, 19) is 2
# The loss value at (19, 9, 19) is 2
# The loss value at (19, 10, 19) is 2
# The loss value at (19, 11, 19) is 2
# The loss value at (19, 12, 19) is 2
# The loss value at (19, 13, 19) is 2
# The loss value at (19, 14, 19) is 2
# The loss value at (19, 15, 19) is 2
# The loss value at (19, 16, 19) is 2
# The loss value at (19, 17, 19) is 2
# The loss value at (19, 18, 19) is 2
# The loss value at (19, 19, 0) is 2
# The loss value at (19, 19, 1) is 2
# The loss value at (19, 19, 2) is 2
# The loss value at (19, 19, 3) is 2
# The loss value at (19, 19, 4) is 2
# The loss value at (19, 19, 5) is 2
# The loss value at (19, 19, 6) is 2
# The loss value at (19, 19, 7) is 2
# The loss value at (19, 19, 8) is 2
# The loss value at (19, 19, 9) is 2
# The loss value at (19, 19, 10) is 2
# The loss value at (19, 19, 11) is 2
# The loss value at (19, 19, 12) is 2
# The loss value at (19, 19, 13) is 2
# The loss value at (19, 19, 14) is 2
# The loss value at (19, 19, 15) is 2
# The loss value at (19, 19, 16) is 2
# The loss value at (19, 19, 17) is 2
# The loss value at (19, 19, 18) is 2
# The loss value at (19, 19, 19) is 2
# The shape of the data matrix is (20, 20, 20)
# The data matrix is [[[2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   ...
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]]
#
#  [[2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   ...
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]]
#
#  [[2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   ...
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]]
#
#  ...
#
#  [[2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   ...
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]]
#
#  [[2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   ...
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]]
#
#  [[2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   ...
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]]]
# (20, 20, 20)

# %%
# save the binary file
np.save('n_dim_loss_binary_files/mlp_cifar10_dim_' + str(DIM) + '_steps_' + str(STEPS) + '.npy', loss_data_fin_n_dim)
